# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
iris = load_iris()
# Out:
# 2022-07-28 19:11:20.792100: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-07-28 19:11:20.792139: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# Load data into a DataFrame
df = pd.DataFrame(iris.data, columns=iris.feature_names)
# Convert datatype to float
df = df.astype(float)
# append "target" and name it "label"
df['label'] = iris.target
# Use string label instead
df['label'] = df.label.replace(dict(enumerate(iris.target_names)))

# %%
# label -> one-hot encoding
label = pd.get_dummies(df['label'], prefix='label')
df = pd.concat([df, label], axis=1)
# drop old label
df.drop(['label'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    label_setosa  label_versicolor  label_virginica
# 0             1                 0                0
# 1             1                 0                0
# 2             1                 0                0
# 3             1                 0                0
# 4             1                 0                0

# %%
# Creating X and y

X = df[['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']]
# Convert DataFrame into np array
X = np.asarray(X)

y = df[['label_setosa', 'label_versicolor', 'label_virginica']]
# Convert DataFrame into np array
y = np.asarray(y)

# %%
# Split the data set in a training set (80%) and a test set (20%)
X_train, X_test, y_train, y_test = train_test_split(
  X,
  y,
  test_size=0.20
)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (120, 4)
# (30, 4)
# (120, 3)
# (30, 3)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization

# %%
# Model without batch normalization
model = Sequential([
    Dense(64, input_shape=(4,), activation="relu"),
    Dense(128, activation='relu'),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(64, activation='relu'),
    Dense(3, activation='softmax')
]);

model.summary()
# Out:
# 2022-07-28 19:13:13.571826: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-07-28 19:13:13.571856: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-07-28 19:13:13.571891: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (fedora): /proc/driver/nvidia/version does not exist
# 2022-07-28 19:13:13.640837: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                320
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  dense_5 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 37,763
# Trainable params: 37,763
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Model with batch normalization
model = Sequential([
    Dense(64, input_shape=(4,), activation="relu"),
    BatchNormalization(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dense(3, activation='softmax')
]);

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 64)                320
#
#  batch_normalization (BatchN  (None, 64)               256
#  ormalization)
#
#  dense_7 (Dense)             (None, 128)               8320
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_8 (Dense)             (None, 128)               16512
#
#  batch_normalization_2 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_9 (Dense)             (None, 64)                8256
#
#  batch_normalization_3 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_10 (Dense)            (None, 64)                4160
#
#  batch_normalization_4 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_11 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 39,555
# Trainable params: 38,659
# Non-trainable params: 896
# _________________________________________________________________

# %%
from tensorflow.keras.initializers import RandomNormal, Constant

# Model with a customized batch normalization
model = Sequential([
    Dense(64, input_shape=(4,), activation="relu"),
    BatchNormalization(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(
        momentum=0.95, 
        epsilon=0.005,
        beta_initializer=RandomNormal(mean=0.0, stddev=0.05), 
        gamma_initializer=Constant(value=0.9)
    ),
    Dense(3, activation='softmax')
]);

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 64)                320
#
#  batch_normalization_5 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_13 (Dense)            (None, 128)               8320
#
#  batch_normalization_6 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_14 (Dense)            (None, 128)               16512
#
#  batch_normalization_7 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_15 (Dense)            (None, 64)                8256
#
#  batch_normalization_8 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_16 (Dense)            (None, 64)                4160
#
#  batch_normalization_9 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_17 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 39,555
# Trainable params: 38,659
# Non-trainable params: 896
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam', 
    loss='categorical_crossentropy', 
    metrics=['accuracy']
)

# %%
history = model.fit(
    X_train, 
    y_train, 
    epochs=200, 
    validation_split=0.25, 
    batch_size=40, 
    verbose=2
)
# Out:
# Epoch 1/200
# 3/3 - 4s - loss: 1.3248 - accuracy: 0.3889 - val_loss: 1.0925 - val_accuracy: 0.4333 - 4s/epoch - 1s/step
# Epoch 2/200
# 3/3 - 0s - loss: 0.3349 - accuracy: 0.9111 - val_loss: 1.0703 - val_accuracy: 0.4333 - 45ms/epoch - 15ms/step
# Epoch 3/200
# 3/3 - 0s - loss: 0.1401 - accuracy: 0.9778 - val_loss: 1.0556 - val_accuracy: 0.4333 - 43ms/epoch - 14ms/step
# Epoch 4/200
# 3/3 - 0s - loss: 0.1148 - accuracy: 0.9778 - val_loss: 1.0491 - val_accuracy: 0.4333 - 40ms/epoch - 13ms/step
# Epoch 5/200
# 3/3 - 0s - loss: 0.1727 - accuracy: 0.9333 - val_loss: 1.0438 - val_accuracy: 0.4667 - 44ms/epoch - 15ms/step
# Epoch 6/200
# 3/3 - 0s - loss: 0.0983 - accuracy: 0.9667 - val_loss: 1.0466 - val_accuracy: 0.5333 - 44ms/epoch - 15ms/step
# Epoch 7/200
# 3/3 - 0s - loss: 0.0942 - accuracy: 0.9778 - val_loss: 1.0502 - val_accuracy: 0.5000 - 42ms/epoch - 14ms/step
# Epoch 8/200
# 3/3 - 0s - loss: 0.0540 - accuracy: 0.9889 - val_loss: 1.0543 - val_accuracy: 0.6333 - 45ms/epoch - 15ms/step
# Epoch 9/200
# 3/3 - 0s - loss: 0.1108 - accuracy: 0.9667 - val_loss: 1.0569 - val_accuracy: 0.5667 - 39ms/epoch - 13ms/step
# Epoch 10/200
# 3/3 - 0s - loss: 0.0644 - accuracy: 0.9889 - val_loss: 1.0541 - val_accuracy: 0.6000 - 46ms/epoch - 15ms/step
# Epoch 11/200
# 3/3 - 0s - loss: 0.0812 - accuracy: 0.9667 - val_loss: 1.0468 - val_accuracy: 0.6000 - 43ms/epoch - 14ms/step
# Epoch 12/200
# 3/3 - 0s - loss: 0.0550 - accuracy: 1.0000 - val_loss: 1.0427 - val_accuracy: 0.4333 - 38ms/epoch - 13ms/step
# Epoch 13/200
# 3/3 - 0s - loss: 0.0580 - accuracy: 1.0000 - val_loss: 1.0353 - val_accuracy: 0.4333 - 41ms/epoch - 14ms/step
# Epoch 14/200
# 3/3 - 0s - loss: 0.0516 - accuracy: 0.9889 - val_loss: 1.0284 - val_accuracy: 0.4667 - 39ms/epoch - 13ms/step
# Epoch 15/200
# 3/3 - 0s - loss: 0.1431 - accuracy: 0.9667 - val_loss: 1.0150 - val_accuracy: 0.5333 - 43ms/epoch - 14ms/step
# Epoch 16/200
# 3/3 - 0s - loss: 0.0406 - accuracy: 0.9889 - val_loss: 1.0117 - val_accuracy: 0.5667 - 42ms/epoch - 14ms/step
# Epoch 17/200
# 3/3 - 0s - loss: 0.0262 - accuracy: 1.0000 - val_loss: 1.0038 - val_accuracy: 0.6667 - 43ms/epoch - 14ms/step
# Epoch 18/200
# 3/3 - 0s - loss: 0.0290 - accuracy: 1.0000 - val_loss: 0.9996 - val_accuracy: 0.6333 - 34ms/epoch - 11ms/step
# Epoch 19/200
# 3/3 - 0s - loss: 0.0639 - accuracy: 0.9667 - val_loss: 0.9868 - val_accuracy: 0.5333 - 41ms/epoch - 14ms/step
# Epoch 20/200
# 3/3 - 0s - loss: 0.1068 - accuracy: 0.9667 - val_loss: 0.9724 - val_accuracy: 0.5000 - 38ms/epoch - 13ms/step
# Epoch 21/200
# 3/3 - 0s - loss: 0.0225 - accuracy: 1.0000 - val_loss: 0.9666 - val_accuracy: 0.5000 - 38ms/epoch - 13ms/step
# Epoch 22/200
# 3/3 - 0s - loss: 0.1090 - accuracy: 0.9778 - val_loss: 0.9686 - val_accuracy: 0.6000 - 57ms/epoch - 19ms/step
# Epoch 23/200
# 3/3 - 0s - loss: 0.0900 - accuracy: 0.9667 - val_loss: 0.9786 - val_accuracy: 0.3000 - 40ms/epoch - 13ms/step
# Epoch 24/200
# 3/3 - 0s - loss: 0.0925 - accuracy: 0.9556 - val_loss: 0.9668 - val_accuracy: 0.3000 - 41ms/epoch - 14ms/step
# Epoch 25/200
# 3/3 - 0s - loss: 0.1110 - accuracy: 0.9556 - val_loss: 0.9453 - val_accuracy: 0.3000 - 37ms/epoch - 12ms/step
# Epoch 26/200
# 3/3 - 0s - loss: 0.0683 - accuracy: 0.9667 - val_loss: 0.9238 - val_accuracy: 0.3000 - 39ms/epoch - 13ms/step
# Epoch 27/200
# 3/3 - 0s - loss: 0.0362 - accuracy: 1.0000 - val_loss: 0.8967 - val_accuracy: 0.4667 - 40ms/epoch - 13ms/step
# Epoch 28/200
# 3/3 - 0s - loss: 0.1444 - accuracy: 0.9444 - val_loss: 0.8835 - val_accuracy: 0.4000 - 44ms/epoch - 15ms/step
# Epoch 29/200
# 3/3 - 0s - loss: 0.0625 - accuracy: 0.9778 - val_loss: 0.8778 - val_accuracy: 0.5333 - 39ms/epoch - 13ms/step
# Epoch 30/200
# 3/3 - 0s - loss: 0.0695 - accuracy: 0.9778 - val_loss: 0.8706 - val_accuracy: 0.5000 - 40ms/epoch - 13ms/step
# Epoch 31/200
# 3/3 - 0s - loss: 0.0412 - accuracy: 0.9889 - val_loss: 0.8573 - val_accuracy: 0.4667 - 43ms/epoch - 14ms/step
# Epoch 32/200
# 3/3 - 0s - loss: 0.0269 - accuracy: 1.0000 - val_loss: 0.8444 - val_accuracy: 0.4667 - 37ms/epoch - 12ms/step
# Epoch 33/200
# 3/3 - 0s - loss: 0.0315 - accuracy: 0.9889 - val_loss: 0.8300 - val_accuracy: 0.4667 - 41ms/epoch - 14ms/step
# Epoch 34/200
# 3/3 - 0s - loss: 0.0384 - accuracy: 1.0000 - val_loss: 0.8196 - val_accuracy: 0.5333 - 38ms/epoch - 13ms/step
# Epoch 35/200
# 3/3 - 0s - loss: 0.0509 - accuracy: 0.9889 - val_loss: 0.8026 - val_accuracy: 0.5333 - 53ms/epoch - 18ms/step
# Epoch 36/200
# 3/3 - 0s - loss: 0.0742 - accuracy: 0.9667 - val_loss: 0.8135 - val_accuracy: 0.5333 - 38ms/epoch - 13ms/step
# Epoch 37/200
# 3/3 - 0s - loss: 0.0198 - accuracy: 1.0000 - val_loss: 0.8124 - val_accuracy: 0.5333 - 40ms/epoch - 13ms/step
# Epoch 38/200
# 3/3 - 0s - loss: 0.0660 - accuracy: 0.9889 - val_loss: 0.8113 - val_accuracy: 0.5333 - 39ms/epoch - 13ms/step
# Epoch 39/200
# 3/3 - 0s - loss: 0.1972 - accuracy: 0.9556 - val_loss: 0.8030 - val_accuracy: 0.5333 - 38ms/epoch - 13ms/step
# Epoch 40/200
# 3/3 - 0s - loss: 0.0524 - accuracy: 0.9889 - val_loss: 0.8080 - val_accuracy: 0.5333 - 37ms/epoch - 12ms/step
# Epoch 41/200
# 3/3 - 0s - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.8055 - val_accuracy: 0.5333 - 39ms/epoch - 13ms/step
# Epoch 42/200
# 3/3 - 0s - loss: 0.0684 - accuracy: 0.9778 - val_loss: 0.7962 - val_accuracy: 0.5333 - 38ms/epoch - 13ms/step
# Epoch 43/200
# 3/3 - 0s - loss: 0.0183 - accuracy: 1.0000 - val_loss: 0.7686 - val_accuracy: 0.5333 - 39ms/epoch - 13ms/step
# Epoch 44/200
# 3/3 - 0s - loss: 0.0376 - accuracy: 0.9889 - val_loss: 0.7440 - val_accuracy: 0.5333 - 38ms/epoch - 13ms/step
# Epoch 45/200
# 3/3 - 0s - loss: 0.0446 - accuracy: 0.9889 - val_loss: 0.7182 - val_accuracy: 0.5667 - 69ms/epoch - 23ms/step
# Epoch 46/200
# 3/3 - 0s - loss: 0.0313 - accuracy: 1.0000 - val_loss: 0.6803 - val_accuracy: 0.6000 - 65ms/epoch - 22ms/step
# Epoch 47/200
# 3/3 - 0s - loss: 0.0272 - accuracy: 0.9889 - val_loss: 0.6412 - val_accuracy: 0.7000 - 56ms/epoch - 19ms/step
# Epoch 48/200
# 3/3 - 0s - loss: 0.0447 - accuracy: 0.9889 - val_loss: 0.5956 - val_accuracy: 0.7667 - 42ms/epoch - 14ms/step
# Epoch 49/200
# 3/3 - 0s - loss: 0.0567 - accuracy: 0.9778 - val_loss: 0.5510 - val_accuracy: 0.7667 - 38ms/epoch - 13ms/step
# Epoch 50/200
# 3/3 - 0s - loss: 0.0922 - accuracy: 0.9667 - val_loss: 0.5091 - val_accuracy: 0.8333 - 43ms/epoch - 14ms/step
# Epoch 51/200
# 3/3 - 0s - loss: 0.0735 - accuracy: 0.9778 - val_loss: 0.4758 - val_accuracy: 0.8333 - 44ms/epoch - 15ms/step
# Epoch 52/200
# 3/3 - 0s - loss: 0.0846 - accuracy: 0.9667 - val_loss: 0.4597 - val_accuracy: 0.8333 - 38ms/epoch - 13ms/step
# Epoch 53/200
# 3/3 - 0s - loss: 0.0853 - accuracy: 0.9778 - val_loss: 0.4573 - val_accuracy: 0.8333 - 43ms/epoch - 14ms/step
# Epoch 54/200
# 3/3 - 0s - loss: 0.0461 - accuracy: 0.9778 - val_loss: 0.4661 - val_accuracy: 0.8000 - 37ms/epoch - 12ms/step
# Epoch 55/200
# 3/3 - 0s - loss: 0.0294 - accuracy: 0.9889 - val_loss: 0.4852 - val_accuracy: 0.8000 - 39ms/epoch - 13ms/step
# Epoch 56/200
# 3/3 - 0s - loss: 0.0819 - accuracy: 0.9778 - val_loss: 0.5115 - val_accuracy: 0.8000 - 41ms/epoch - 14ms/step
# Epoch 57/200
# 3/3 - 0s - loss: 0.0760 - accuracy: 0.9778 - val_loss: 0.5478 - val_accuracy: 0.8000 - 40ms/epoch - 13ms/step
# Epoch 58/200
# 3/3 - 0s - loss: 0.1028 - accuracy: 0.9556 - val_loss: 0.5785 - val_accuracy: 0.8000 - 46ms/epoch - 15ms/step
# Epoch 59/200
# 3/3 - 0s - loss: 0.0499 - accuracy: 0.9889 - val_loss: 0.5918 - val_accuracy: 0.8000 - 37ms/epoch - 12ms/step
# Epoch 60/200
# 3/3 - 0s - loss: 0.0774 - accuracy: 0.9667 - val_loss: 0.5338 - val_accuracy: 0.8000 - 43ms/epoch - 14ms/step
# Epoch 61/200
# 3/3 - 0s - loss: 0.0448 - accuracy: 1.0000 - val_loss: 0.4840 - val_accuracy: 0.8333 - 37ms/epoch - 12ms/step
# Epoch 62/200
# 3/3 - 0s - loss: 0.0381 - accuracy: 0.9889 - val_loss: 0.4411 - val_accuracy: 0.8333 - 41ms/epoch - 14ms/step
# Epoch 63/200
# 3/3 - 0s - loss: 0.0264 - accuracy: 1.0000 - val_loss: 0.4071 - val_accuracy: 0.8333 - 36ms/epoch - 12ms/step
# Epoch 64/200
# 3/3 - 0s - loss: 0.0247 - accuracy: 1.0000 - val_loss: 0.3826 - val_accuracy: 0.8333 - 43ms/epoch - 14ms/step
# Epoch 65/200
# 3/3 - 0s - loss: 0.0236 - accuracy: 1.0000 - val_loss: 0.3623 - val_accuracy: 0.8333 - 38ms/epoch - 13ms/step
# Epoch 66/200
# 3/3 - 0s - loss: 0.0851 - accuracy: 0.9778 - val_loss: 0.3202 - val_accuracy: 0.8667 - 45ms/epoch - 15ms/step
# Epoch 67/200
# 3/3 - 0s - loss: 0.0281 - accuracy: 0.9889 - val_loss: 0.2625 - val_accuracy: 0.9000 - 42ms/epoch - 14ms/step
# Epoch 68/200
# 3/3 - 0s - loss: 0.0380 - accuracy: 1.0000 - val_loss: 0.2477 - val_accuracy: 0.9333 - 38ms/epoch - 13ms/step
# Epoch 69/200
# 3/3 - 0s - loss: 0.0400 - accuracy: 0.9889 - val_loss: 0.2462 - val_accuracy: 0.9000 - 41ms/epoch - 14ms/step
# Epoch 70/200
# 3/3 - 0s - loss: 0.0337 - accuracy: 0.9889 - val_loss: 0.2382 - val_accuracy: 0.9333 - 49ms/epoch - 16ms/step
# Epoch 71/200
# 3/3 - 0s - loss: 0.0174 - accuracy: 1.0000 - val_loss: 0.2322 - val_accuracy: 0.9000 - 43ms/epoch - 14ms/step
# Epoch 72/200
# 3/3 - 0s - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.2397 - val_accuracy: 0.9000 - 38ms/epoch - 13ms/step
# Epoch 73/200
# 3/3 - 0s - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.2558 - val_accuracy: 0.9000 - 55ms/epoch - 18ms/step
# Epoch 74/200
# 3/3 - 0s - loss: 0.0973 - accuracy: 0.9667 - val_loss: 0.2561 - val_accuracy: 0.9000 - 42ms/epoch - 14ms/step
# Epoch 75/200
# 3/3 - 0s - loss: 0.0434 - accuracy: 0.9889 - val_loss: 0.2288 - val_accuracy: 0.9000 - 57ms/epoch - 19ms/step
# Epoch 76/200
# 3/3 - 0s - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.2086 - val_accuracy: 0.9000 - 42ms/epoch - 14ms/step
# Epoch 77/200
# 3/3 - 0s - loss: 0.0242 - accuracy: 0.9889 - val_loss: 0.1974 - val_accuracy: 0.9000 - 40ms/epoch - 13ms/step
# Epoch 78/200
# 3/3 - 0s - loss: 0.0277 - accuracy: 1.0000 - val_loss: 0.1858 - val_accuracy: 0.9000 - 46ms/epoch - 15ms/step
# Epoch 79/200
# 3/3 - 0s - loss: 0.0319 - accuracy: 0.9889 - val_loss: 0.1828 - val_accuracy: 0.9000 - 41ms/epoch - 14ms/step
# Epoch 80/200
# 3/3 - 0s - loss: 0.0675 - accuracy: 0.9778 - val_loss: 0.1976 - val_accuracy: 0.9000 - 41ms/epoch - 14ms/step
# Epoch 81/200
# 3/3 - 0s - loss: 0.0622 - accuracy: 0.9889 - val_loss: 0.1978 - val_accuracy: 0.9000 - 40ms/epoch - 13ms/step
# Epoch 82/200
# 3/3 - 0s - loss: 0.0536 - accuracy: 0.9778 - val_loss: 0.1901 - val_accuracy: 0.9000 - 41ms/epoch - 14ms/step
# Epoch 83/200
# 3/3 - 0s - loss: 0.0389 - accuracy: 0.9778 - val_loss: 0.1785 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 84/200
# 3/3 - 0s - loss: 0.1317 - accuracy: 0.9667 - val_loss: 0.1759 - val_accuracy: 0.9333 - 36ms/epoch - 12ms/step
# Epoch 85/200
# 3/3 - 0s - loss: 0.0183 - accuracy: 1.0000 - val_loss: 0.1646 - val_accuracy: 0.9333 - 57ms/epoch - 19ms/step
# Epoch 86/200
# 3/3 - 0s - loss: 0.1338 - accuracy: 0.9778 - val_loss: 0.1582 - val_accuracy: 0.9333 - 40ms/epoch - 13ms/step
# Epoch 87/200
# 3/3 - 0s - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.1601 - val_accuracy: 0.9333 - 45ms/epoch - 15ms/step
# Epoch 88/200
# 3/3 - 0s - loss: 0.1284 - accuracy: 0.9556 - val_loss: 0.1648 - val_accuracy: 0.9333 - 38ms/epoch - 13ms/step
# Epoch 89/200
# 3/3 - 0s - loss: 0.0212 - accuracy: 1.0000 - val_loss: 0.1794 - val_accuracy: 0.9333 - 37ms/epoch - 12ms/step
# Epoch 90/200
# 3/3 - 0s - loss: 0.0312 - accuracy: 0.9889 - val_loss: 0.1843 - val_accuracy: 0.9333 - 38ms/epoch - 13ms/step
# Epoch 91/200
# 3/3 - 0s - loss: 0.0499 - accuracy: 0.9889 - val_loss: 0.1760 - val_accuracy: 0.9333 - 42ms/epoch - 14ms/step
# Epoch 92/200
# 3/3 - 0s - loss: 0.0529 - accuracy: 0.9889 - val_loss: 0.1659 - val_accuracy: 0.9333 - 38ms/epoch - 13ms/step
# Epoch 93/200
# 3/3 - 0s - loss: 0.0249 - accuracy: 1.0000 - val_loss: 0.1586 - val_accuracy: 0.9333 - 41ms/epoch - 14ms/step
# Epoch 94/200
# 3/3 - 0s - loss: 0.1080 - accuracy: 0.9778 - val_loss: 0.1439 - val_accuracy: 0.9333 - 36ms/epoch - 12ms/step
# Epoch 95/200
# 3/3 - 0s - loss: 0.0265 - accuracy: 1.0000 - val_loss: 0.1205 - val_accuracy: 1.0000 - 41ms/epoch - 14ms/step
# Epoch 96/200
# 3/3 - 0s - loss: 0.0286 - accuracy: 1.0000 - val_loss: 0.1100 - val_accuracy: 1.0000 - 37ms/epoch - 12ms/step
# Epoch 97/200
# 3/3 - 0s - loss: 0.0881 - accuracy: 0.9444 - val_loss: 0.1028 - val_accuracy: 1.0000 - 40ms/epoch - 13ms/step
# Epoch 98/200
# 3/3 - 0s - loss: 0.0211 - accuracy: 1.0000 - val_loss: 0.0920 - val_accuracy: 1.0000 - 38ms/epoch - 13ms/step
# Epoch 99/200
# 3/3 - 0s - loss: 0.0180 - accuracy: 1.0000 - val_loss: 0.0879 - val_accuracy: 1.0000 - 39ms/epoch - 13ms/step
# Epoch 100/200
# 3/3 - 0s - loss: 0.0234 - accuracy: 0.9889 - val_loss: 0.0910 - val_accuracy: 0.9333 - 37ms/epoch - 12ms/step
# Epoch 101/200
# 3/3 - 0s - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.0978 - val_accuracy: 0.9333 - 42ms/epoch - 14ms/step
# Epoch 102/200
# 3/3 - 0s - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.0993 - val_accuracy: 0.9333 - 44ms/epoch - 15ms/step
# Epoch 103/200
# 3/3 - 0s - loss: 0.0379 - accuracy: 0.9889 - val_loss: 0.0840 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 104/200
# 3/3 - 0s - loss: 0.0929 - accuracy: 0.9667 - val_loss: 0.0680 - val_accuracy: 1.0000 - 37ms/epoch - 12ms/step
# Epoch 105/200
# 3/3 - 0s - loss: 0.0241 - accuracy: 1.0000 - val_loss: 0.0728 - val_accuracy: 1.0000 - 40ms/epoch - 13ms/step
# Epoch 106/200
# 3/3 - 0s - loss: 0.0330 - accuracy: 0.9778 - val_loss: 0.0847 - val_accuracy: 1.0000 - 40ms/epoch - 13ms/step
# Epoch 107/200
# 3/3 - 0s - loss: 0.0479 - accuracy: 0.9889 - val_loss: 0.0749 - val_accuracy: 1.0000 - 37ms/epoch - 12ms/step
# Epoch 108/200
# 3/3 - 0s - loss: 0.0217 - accuracy: 1.0000 - val_loss: 0.0704 - val_accuracy: 1.0000 - 40ms/epoch - 13ms/step
# Epoch 109/200
# 3/3 - 0s - loss: 0.0710 - accuracy: 0.9889 - val_loss: 0.0662 - val_accuracy: 1.0000 - 39ms/epoch - 13ms/step
# Epoch 110/200
# 3/3 - 0s - loss: 0.0635 - accuracy: 0.9889 - val_loss: 0.0782 - val_accuracy: 0.9667 - 50ms/epoch - 17ms/step
# Epoch 111/200
# 3/3 - 0s - loss: 0.0285 - accuracy: 0.9889 - val_loss: 0.1179 - val_accuracy: 0.9333 - 42ms/epoch - 14ms/step
# Epoch 112/200
# 3/3 - 0s - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.1619 - val_accuracy: 0.9333 - 38ms/epoch - 13ms/step
# Epoch 113/200
# 3/3 - 0s - loss: 0.0206 - accuracy: 1.0000 - val_loss: 0.1836 - val_accuracy: 0.9333 - 42ms/epoch - 14ms/step
# Epoch 114/200
# 3/3 - 0s - loss: 0.0257 - accuracy: 0.9889 - val_loss: 0.1837 - val_accuracy: 0.9333 - 37ms/epoch - 12ms/step
# Epoch 115/200
# 3/3 - 0s - loss: 0.0422 - accuracy: 0.9889 - val_loss: 0.1762 - val_accuracy: 0.9333 - 45ms/epoch - 15ms/step
# Epoch 116/200
# 3/3 - 0s - loss: 0.0306 - accuracy: 0.9889 - val_loss: 0.1644 - val_accuracy: 0.9333 - 41ms/epoch - 14ms/step
# Epoch 117/200
# 3/3 - 0s - loss: 0.0312 - accuracy: 1.0000 - val_loss: 0.1285 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 118/200
# 3/3 - 0s - loss: 0.0857 - accuracy: 0.9667 - val_loss: 0.1075 - val_accuracy: 0.9333 - 43ms/epoch - 14ms/step
# Epoch 119/200
# 3/3 - 0s - loss: 0.0378 - accuracy: 0.9889 - val_loss: 0.1024 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 120/200
# 3/3 - 0s - loss: 0.0704 - accuracy: 0.9778 - val_loss: 0.1119 - val_accuracy: 0.9667 - 42ms/epoch - 14ms/step
# Epoch 121/200
# 3/3 - 0s - loss: 0.0587 - accuracy: 0.9778 - val_loss: 0.1422 - val_accuracy: 0.9667 - 39ms/epoch - 13ms/step
# Epoch 122/200
# 3/3 - 0s - loss: 0.0431 - accuracy: 0.9889 - val_loss: 0.1389 - val_accuracy: 0.9667 - 46ms/epoch - 15ms/step
# Epoch 123/200
# 3/3 - 0s - loss: 0.0203 - accuracy: 1.0000 - val_loss: 0.1263 - val_accuracy: 1.0000 - 44ms/epoch - 15ms/step
# Epoch 124/200
# 3/3 - 0s - loss: 0.0350 - accuracy: 1.0000 - val_loss: 0.1061 - val_accuracy: 1.0000 - 40ms/epoch - 13ms/step
# Epoch 125/200
# 3/3 - 0s - loss: 0.0323 - accuracy: 1.0000 - val_loss: 0.0926 - val_accuracy: 1.0000 - 42ms/epoch - 14ms/step
# Epoch 126/200
# 3/3 - 0s - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.0930 - val_accuracy: 1.0000 - 39ms/epoch - 13ms/step
# Epoch 127/200
# 3/3 - 0s - loss: 0.0216 - accuracy: 1.0000 - val_loss: 0.0948 - val_accuracy: 1.0000 - 41ms/epoch - 14ms/step
# Epoch 128/200
# 3/3 - 0s - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.0999 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 129/200
# 3/3 - 0s - loss: 0.1310 - accuracy: 0.9444 - val_loss: 0.0952 - val_accuracy: 0.9333 - 38ms/epoch - 13ms/step
# Epoch 130/200
# 3/3 - 0s - loss: 0.0362 - accuracy: 0.9889 - val_loss: 0.0838 - val_accuracy: 0.9667 - 45ms/epoch - 15ms/step
# Epoch 131/200
# 3/3 - 0s - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.0782 - val_accuracy: 1.0000 - 45ms/epoch - 15ms/step
# Epoch 132/200
# 3/3 - 0s - loss: 0.0260 - accuracy: 0.9889 - val_loss: 0.0721 - val_accuracy: 1.0000 - 58ms/epoch - 19ms/step
# Epoch 133/200
# 3/3 - 0s - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.0687 - val_accuracy: 1.0000 - 41ms/epoch - 14ms/step
# Epoch 134/200
# 3/3 - 0s - loss: 0.0191 - accuracy: 1.0000 - val_loss: 0.0672 - val_accuracy: 1.0000 - 41ms/epoch - 14ms/step
# Epoch 135/200
# 3/3 - 0s - loss: 0.0439 - accuracy: 0.9889 - val_loss: 0.0629 - val_accuracy: 1.0000 - 37ms/epoch - 12ms/step
# Epoch 136/200
# 3/3 - 0s - loss: 0.2131 - accuracy: 0.9556 - val_loss: 0.0698 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 137/200
# 3/3 - 0s - loss: 0.1475 - accuracy: 0.9444 - val_loss: 0.0872 - val_accuracy: 0.9667 - 39ms/epoch - 13ms/step
# Epoch 138/200
# 3/3 - 0s - loss: 0.0445 - accuracy: 0.9889 - val_loss: 0.1057 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 139/200
# 3/3 - 0s - loss: 0.0325 - accuracy: 1.0000 - val_loss: 0.1180 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 140/200
# 3/3 - 0s - loss: 0.0290 - accuracy: 1.0000 - val_loss: 0.1215 - val_accuracy: 0.9667 - 39ms/epoch - 13ms/step
# Epoch 141/200
# 3/3 - 0s - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.1206 - val_accuracy: 0.9667 - 40ms/epoch - 13ms/step
# Epoch 142/200
# 3/3 - 0s - loss: 0.0370 - accuracy: 0.9889 - val_loss: 0.1250 - val_accuracy: 0.9667 - 46ms/epoch - 15ms/step
# Epoch 143/200
# 3/3 - 0s - loss: 0.0187 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9000 - 44ms/epoch - 15ms/step
# Epoch 144/200
# 3/3 - 0s - loss: 0.0652 - accuracy: 0.9778 - val_loss: 0.1294 - val_accuracy: 0.9333 - 40ms/epoch - 13ms/step
# Epoch 145/200
# 3/3 - 0s - loss: 0.0666 - accuracy: 0.9667 - val_loss: 0.0996 - val_accuracy: 0.9667 - 38ms/epoch - 13ms/step
# Epoch 146/200
# 3/3 - 0s - loss: 0.0465 - accuracy: 0.9889 - val_loss: 0.0899 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 147/200
# 3/3 - 0s - loss: 0.0216 - accuracy: 1.0000 - val_loss: 0.0877 - val_accuracy: 0.9667 - 38ms/epoch - 13ms/step
# Epoch 148/200
# 3/3 - 0s - loss: 0.0151 - accuracy: 1.0000 - val_loss: 0.0864 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 149/200
# 3/3 - 0s - loss: 0.0368 - accuracy: 0.9889 - val_loss: 0.0854 - val_accuracy: 0.9667 - 38ms/epoch - 13ms/step
# Epoch 150/200
# 3/3 - 0s - loss: 0.0579 - accuracy: 0.9778 - val_loss: 0.0870 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 151/200
# 3/3 - 0s - loss: 0.0323 - accuracy: 0.9889 - val_loss: 0.0943 - val_accuracy: 0.9667 - 42ms/epoch - 14ms/step
# Epoch 152/200
# 3/3 - 0s - loss: 0.0134 - accuracy: 1.0000 - val_loss: 0.1096 - val_accuracy: 0.9667 - 36ms/epoch - 12ms/step
# Epoch 153/200
# 3/3 - 0s - loss: 0.0432 - accuracy: 0.9778 - val_loss: 0.1032 - val_accuracy: 0.9667 - 43ms/epoch - 14ms/step
# Epoch 154/200
# 3/3 - 0s - loss: 0.0578 - accuracy: 0.9778 - val_loss: 0.0895 - val_accuracy: 0.9667 - 38ms/epoch - 13ms/step
# Epoch 155/200
# 3/3 - 0s - loss: 0.0345 - accuracy: 1.0000 - val_loss: 0.0734 - val_accuracy: 0.9667 - 43ms/epoch - 14ms/step
# Epoch 156/200
# 3/3 - 0s - loss: 0.0611 - accuracy: 0.9778 - val_loss: 0.0840 - val_accuracy: 1.0000 - 38ms/epoch - 13ms/step
# Epoch 157/200
# 3/3 - 0s - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.1605 - val_accuracy: 0.8667 - 42ms/epoch - 14ms/step
# Epoch 158/200
# 3/3 - 0s - loss: 0.0224 - accuracy: 1.0000 - val_loss: 0.2558 - val_accuracy: 0.8333 - 40ms/epoch - 13ms/step
# Epoch 159/200
# 3/3 - 0s - loss: 0.0302 - accuracy: 0.9889 - val_loss: 0.3268 - val_accuracy: 0.8333 - 37ms/epoch - 12ms/step
# Epoch 160/200
# 3/3 - 0s - loss: 0.0278 - accuracy: 1.0000 - val_loss: 0.3195 - val_accuracy: 0.8333 - 38ms/epoch - 13ms/step
# Epoch 161/200
# 3/3 - 0s - loss: 0.0199 - accuracy: 1.0000 - val_loss: 0.2388 - val_accuracy: 0.8333 - 43ms/epoch - 14ms/step
# Epoch 162/200
# 3/3 - 0s - loss: 0.0275 - accuracy: 0.9889 - val_loss: 0.1476 - val_accuracy: 0.9333 - 38ms/epoch - 13ms/step
# Epoch 163/200
# 3/3 - 0s - loss: 0.0542 - accuracy: 0.9778 - val_loss: 0.0909 - val_accuracy: 0.9667 - 39ms/epoch - 13ms/step
# Epoch 164/200
# 3/3 - 0s - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.0845 - val_accuracy: 0.9667 - 38ms/epoch - 13ms/step
# Epoch 165/200
# 3/3 - 0s - loss: 0.0214 - accuracy: 1.0000 - val_loss: 0.0728 - val_accuracy: 0.9667 - 40ms/epoch - 13ms/step
# Epoch 166/200
# 3/3 - 0s - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.0551 - val_accuracy: 1.0000 - 41ms/epoch - 14ms/step
# Epoch 167/200
# 3/3 - 0s - loss: 0.0183 - accuracy: 1.0000 - val_loss: 0.0407 - val_accuracy: 1.0000 - 39ms/epoch - 13ms/step
# Epoch 168/200
# 3/3 - 0s - loss: 0.0183 - accuracy: 1.0000 - val_loss: 0.0331 - val_accuracy: 1.0000 - 43ms/epoch - 14ms/step
# Epoch 169/200
# 3/3 - 0s - loss: 0.0765 - accuracy: 0.9889 - val_loss: 0.0276 - val_accuracy: 1.0000 - 37ms/epoch - 12ms/step
# Epoch 170/200
# 3/3 - 0s - loss: 0.0157 - accuracy: 1.0000 - val_loss: 0.0262 - val_accuracy: 1.0000 - 41ms/epoch - 14ms/step
# Epoch 171/200
# 3/3 - 0s - loss: 0.0199 - accuracy: 0.9889 - val_loss: 0.0316 - val_accuracy: 1.0000 - 40ms/epoch - 13ms/step
# Epoch 172/200
# 3/3 - 0s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0470 - val_accuracy: 1.0000 - 37ms/epoch - 12ms/step
# Epoch 173/200
# 3/3 - 0s - loss: 0.1016 - accuracy: 0.9556 - val_loss: 0.0602 - val_accuracy: 1.0000 - 39ms/epoch - 13ms/step
# Epoch 174/200
# 3/3 - 0s - loss: 0.0743 - accuracy: 0.9889 - val_loss: 0.0600 - val_accuracy: 1.0000 - 37ms/epoch - 12ms/step
# Epoch 175/200
# 3/3 - 0s - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.0618 - val_accuracy: 1.0000 - 43ms/epoch - 14ms/step
# Epoch 176/200
# 3/3 - 0s - loss: 0.0734 - accuracy: 0.9889 - val_loss: 0.0594 - val_accuracy: 0.9333 - 37ms/epoch - 12ms/step
# Epoch 177/200
# 3/3 - 0s - loss: 0.2660 - accuracy: 0.9667 - val_loss: 0.0627 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 178/200
# 3/3 - 0s - loss: 0.0444 - accuracy: 0.9778 - val_loss: 0.0795 - val_accuracy: 0.9333 - 36ms/epoch - 12ms/step
# Epoch 179/200
# 3/3 - 0s - loss: 0.0386 - accuracy: 0.9889 - val_loss: 0.1011 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 180/200
# 3/3 - 0s - loss: 0.0595 - accuracy: 0.9889 - val_loss: 0.1109 - val_accuracy: 0.9333 - 38ms/epoch - 13ms/step
# Epoch 181/200
# 3/3 - 0s - loss: 0.0380 - accuracy: 1.0000 - val_loss: 0.1109 - val_accuracy: 0.9333 - 38ms/epoch - 13ms/step
# Epoch 182/200
# 3/3 - 0s - loss: 0.0369 - accuracy: 0.9889 - val_loss: 0.1158 - val_accuracy: 0.9333 - 40ms/epoch - 13ms/step
# Epoch 183/200
# 3/3 - 0s - loss: 0.0342 - accuracy: 0.9889 - val_loss: 0.1133 - val_accuracy: 0.9333 - 40ms/epoch - 13ms/step
# Epoch 184/200
# 3/3 - 0s - loss: 0.0407 - accuracy: 0.9889 - val_loss: 0.1116 - val_accuracy: 0.9333 - 40ms/epoch - 13ms/step
# Epoch 185/200
# 3/3 - 0s - loss: 0.0247 - accuracy: 0.9889 - val_loss: 0.1094 - val_accuracy: 0.9333 - 41ms/epoch - 14ms/step
# Epoch 186/200
# 3/3 - 0s - loss: 0.0497 - accuracy: 0.9889 - val_loss: 0.0949 - val_accuracy: 0.9667 - 85ms/epoch - 28ms/step
# Epoch 187/200
# 3/3 - 0s - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.0896 - val_accuracy: 0.9667 - 61ms/epoch - 20ms/step
# Epoch 188/200
# 3/3 - 0s - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.0892 - val_accuracy: 0.9667 - 38ms/epoch - 13ms/step
# Epoch 189/200
# 3/3 - 0s - loss: 0.0394 - accuracy: 0.9889 - val_loss: 0.0966 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 190/200
# 3/3 - 0s - loss: 0.2199 - accuracy: 0.9556 - val_loss: 0.1291 - val_accuracy: 0.9667 - 36ms/epoch - 12ms/step
# Epoch 191/200
# 3/3 - 0s - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.1953 - val_accuracy: 0.9333 - 46ms/epoch - 15ms/step
# Epoch 192/200
# 3/3 - 0s - loss: 0.0174 - accuracy: 1.0000 - val_loss: 0.2505 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 193/200
# 3/3 - 0s - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.2873 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 194/200
# 3/3 - 0s - loss: 0.0245 - accuracy: 0.9889 - val_loss: 0.3053 - val_accuracy: 0.9333 - 41ms/epoch - 14ms/step
# Epoch 195/200
# 3/3 - 0s - loss: 0.0492 - accuracy: 1.0000 - val_loss: 0.3140 - val_accuracy: 0.9333 - 38ms/epoch - 13ms/step
# Epoch 196/200
# 3/3 - 0s - loss: 0.0207 - accuracy: 1.0000 - val_loss: 0.3050 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 197/200
# 3/3 - 0s - loss: 0.0545 - accuracy: 0.9889 - val_loss: 0.2592 - val_accuracy: 0.9333 - 38ms/epoch - 13ms/step
# Epoch 198/200
# 3/3 - 0s - loss: 0.0324 - accuracy: 0.9778 - val_loss: 0.1748 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 199/200
# 3/3 - 0s - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.1393 - val_accuracy: 0.9333 - 38ms/epoch - 13ms/step
# Epoch 200/200
# 3/3 - 0s - loss: 0.1193 - accuracy: 0.9667 - val_loss: 0.1383 - val_accuracy: 0.9333 - 43ms/epoch - 14ms/step

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
def plot_metric(history, metric):
    train_metrics = history.history[metric]
    val_metrics = history.history['val_'+metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics)
    plt.plot(epochs, val_metrics)
    plt.title('Training and validation '+ metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric, 'val_'+metric])
    plt.show()

# %%
plot_metric(history, 'accuracy')

# %%
plot_metric(history, 'loss')

# %%
# Evaluate the model on the test set
model.evaluate(X_test, y_test, verbose=2)
# Out:
# 1/1 - 0s - loss: 0.1277 - accuracy: 0.9333 - 18ms/epoch - 18ms/step
# [0.12767425179481506, 0.9333333373069763]
